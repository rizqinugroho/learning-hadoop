# %% [markdown]
# Spark ditulis dalam bahasa Scala dan membutuhkan Java Virtual Machine (JVM) untuk bisa berjalan. Maka dari itu, kita membutuhkan java untuk dia bisa berjalan diatasnya

# %%
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null

# %% [markdown]
# Next, kita download and unzip Apache Spark with Hadoop 2.7 lalu menginstallnya.

# %%
# !wget -q https://archive.apache.org/dist/spark/spark-3.2.1/spark-3.2.1-bin-hadoop2.7.tgz
# !tar xf spark-3.2.1-bin-hadoop2.7.tgz

# %% [markdown]
# set the ‘environment’ path.

# %%
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-3.2.1-bin-hadoop2.7/bin"

# %% [markdown]
# Lalu, kita. butuh menginstall **Findspark** library yang akan mencari spark dalam sistem dan akan menginstallnya sebagai regular library.

# %%
# !pip install -q findspark
import findspark
findspark.init("/content/spark-3.2.1-bin-hadoop2.7/", edit_rc=True)

# %% [markdown]
# Sekarang, kita bisa import SparkSession dari pyspark.sql and membuat  SparkSession, yang merupakan pintu gerbang to Spark.

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder\
        .master("local")\
        .appName("Colab")\
        .config('spark.ui.port', '4050')\
        .getOrCreate()

# %% [markdown]
# I have created a sample JSON dataset in Github. You can download the file directly into Colab using the ‘wget’ command like this

# %%
# !wget --continue https://raw.githubusercontent.com/rizqinugroho/learning-hadoop/learning-spark/sample-books.json -O /tmp/sample_books.json
# Out:
# --2022-02-01 15:44:21--  https://raw.githubusercontent.com/GarvitArya/pyspark-demo/main/sample_books.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1565 (1.5K) [text/plain]
# Saving to: ‘/tmp/sample_books.json’
#
# /tmp/sample_books.j 100%[===================>]   1.53K  --.-KB/s    in 0s
#
# 2022-02-01 15:44:21 (24.9 MB/s) - ‘/tmp/sample_books.json’ saved [1565/1565]

# %% [markdown]
# Spark ditulis dalam bahasa Scala dan membutuhkan Java Virtual Machine (JVM) untuk bisa berjalan. Maka dari itu, kita membutuhkan java untuk dia bisa berjalan diatasnya

# %%
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null

# %% [markdown]
# Next, kita download and unzip Apache Spark with Hadoop 2.7 lalu menginstallnya.

# %%
# !wget -q https://archive.apache.org/dist/spark/spark-3.2.1/spark-3.2.1-bin-hadoop2.7.tgz
# !tar xf spark-3.2.1-bin-hadoop2.7.tgz

# %% [markdown]
# set the ‘environment’ path.

# %%
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-3.2.1-bin-hadoop2.7/bin"

# %% [markdown]
# Lalu, kita. butuh menginstall **Findspark** library yang akan mencari spark dalam sistem dan akan menginstallnya sebagai regular library.

# %%
# !pip install -q findspark
import findspark
findspark.init("/content/spark-3.2.1-bin-hadoop2.7/", edit_rc=True)

# %% [markdown]
# Sekarang, kita bisa import SparkSession dari pyspark.sql and membuat  SparkSession, yang merupakan pintu gerbang to Spark.

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://7312f14e012d:4050">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.2.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Colab</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder\
        .master("local")\
        .appName("Colab")\
        .config('spark.ui.port', '4050')\
        .getOrCreate()

# %% [markdown]
# Download Sample dataset

# %%
# !wget --continue https://raw.githubusercontent.com/rizqinugroho/learning-hadoop/main/learning-spark/sample-books.json -O /tmp/sample-book.json
# Out:
# --2022-02-01 18:35:51--  https://raw.githubusercontent.com/rizqinugroho/learning-hadoop/main/learning-spark/sample-books.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1578 (1.5K) [text/plain]
# Saving to: ‘/tmp/sample-book.json’
#
# /tmp/sample-book.js 100%[===================>]   1.54K  --.-KB/s    in 0s
#
# 2022-02-01 18:35:51 (21.4 MB/s) - ‘/tmp/sample-book.json’ saved [1578/1578]

# %% [markdown]
# Buat sebuah dataframe dari sample file

# %%
df = spark.read.option("multiline","true").json("/tmp/sample-book.json")
df.show()
# Out:
# +--------------------+-----------------+-----+--------------------+------------+
# |              author|          edition|price|               title|year_written|
# +--------------------+-----------------+-----+--------------------+------------+
# |        Austen, Jane|          Penguin| 18.2|    Northanger Abbey|        1814|
# |        Tolstoy, Leo|          Penguin| 12.7|       War and Peace|        1865|
# |        Tolstoy, Leo|          Penguin| 13.5|       Anna Karenina|        1875|
# |     Woolf, Virginia|   Harcourt Brace| 25.0|       Mrs. Dalloway|        1925|
# |Cunnningham, Michael|   Harcourt Brace|12.35|           The Hours|        1999|
# |         Twain, Mark|          Penguin| 5.76|    Huckleberry Finn|        1865|
# |    Dickens, Charles|     Random House| 5.75|         Bleak House|        1870|
# |         Twain, Mark|     Random House| 7.75|          Tom Sawyer|        1862|
# |     Woolf, Virginia|          Penguin| 29.0| A Room of One's Own|        1922|
# |       Rowling, J.K.|   Harcourt Brace|19.95|        Harry Potter|        2000|
# |             Marquez|Harper  Perennial| 14.0|One Hundred Years...|        1967|
# |         Shakespeare| Signet  Classics| 7.95|Hamlet, Prince of...|        1603|
# |       Tolkien, J.R.|          Penguin|27.45|   Lord of the Rings|        1937|
# +--------------------+-----------------+-----+--------------------+------------+

# %% [markdown]
# Print schema

# %%
df.printSchema()
# Out:
# root
#  |-- author: string (nullable = true)
#  |-- edition: string (nullable = true)
#  |-- price: double (nullable = true)
#  |-- title: string (nullable = true)
#  |-- year_written: long (nullable = true)

# %%
df_lenght = df.count()
print(df_lenght)
df.show()
# Out:
# 13
# +--------------------+-----------------+-----+--------------------+------------+
# |              author|          edition|price|               title|year_written|
# +--------------------+-----------------+-----+--------------------+------------+
# |        Austen, Jane|          Penguin| 18.2|    Northanger Abbey|        1814|
# |        Tolstoy, Leo|          Penguin| 12.7|       War and Peace|        1865|
# |        Tolstoy, Leo|          Penguin| 13.5|       Anna Karenina|        1875|
# |     Woolf, Virginia|   Harcourt Brace| 25.0|       Mrs. Dalloway|        1925|
# |Cunnningham, Michael|   Harcourt Brace|12.35|           The Hours|        1999|
# |         Twain, Mark|          Penguin| 5.76|    Huckleberry Finn|        1865|
# |    Dickens, Charles|     Random House| 5.75|         Bleak House|        1870|
# |         Twain, Mark|     Random House| 7.75|          Tom Sawyer|        1862|
# |     Woolf, Virginia|          Penguin| 29.0| A Room of One's Own|        1922|
# |       Rowling, J.K.|   Harcourt Brace|19.95|        Harry Potter|        2000|
# |             Marquez|Harper  Perennial| 14.0|One Hundred Years...|        1967|
# |         Shakespeare| Signet  Classics| 7.95|Hamlet, Prince of...|        1603|
# |       Tolkien, J.R.|          Penguin|27.45|   Lord of the Rings|        1937|
# +--------------------+-----------------+-----+--------------------+------------+

# %%
df.count()
# Out:
# 13

# %%
df.select("title", "price", "year_written").show(5)
# Out:
# +----------------+-----+------------+
# |           title|price|year_written|
# +----------------+-----+------------+
# |Northanger Abbey| 18.2|        1814|
# |   War and Peace| 12.7|        1865|
# |   Anna Karenina| 13.5|        1875|
# |   Mrs. Dalloway| 25.0|        1925|
# |       The Hours|12.35|        1999|
# +----------------+-----+------------+
# only showing top 5 rows

# %% [markdown]
# Salah satu contoh narrow transformation adalah filter

# %%
df_filtered = df.filter("year_written > 1950 AND price > 10 AND title IS NOT NULL")
df_filtered.select("title", "price", "year_written").show(50, truncate=False)
# Out:
# +-----------------------------+-----+------------+
# |title                        |price|year_written|
# +-----------------------------+-----+------------+
# |The Hours                    |12.35|1999        |
# |Harry Potter                 |19.95|2000        |
# |One Hundred Years of Solitude|14.0 |1967        |
# +-----------------------------+-----+------------+

# %% [markdown]
# Spark transformation adalah lazzy maka saat kita mendefine satu syntax dia tidak akan langsung di eksekusi

# %%
modulus = df.where("year_written % 2 =0")

# %% [markdown]
# Eksekusi hanya akan berjalan setelah ada action, berikut sample action .show()

# %%
modulus.select("title", "price", "year_written").show()
# Out:
# +-------------------+-----+------------+
# |              title|price|year_written|
# +-------------------+-----+------------+
# |   Northanger Abbey| 18.2|        1814|
# |        Bleak House| 5.75|        1870|
# |         Tom Sawyer| 7.75|        1862|
# |A Room of One's Own| 29.0|        1922|
# |       Harry Potter|19.95|        2000|
# +-------------------+-----+------------+

# %% [markdown]
# Sample wide transformation adalah groupBy

# %%
df.groupby('edition').count().show()
# Out:
# +-----------------+-----+
# |          edition|count|
# +-----------------+-----+
# |             null| 1150|
# | Signet  Classics|    1|
# |Harper  Perennial|    1|
# |     Random House|    2|
# |   Harcourt Brace|    3|
# |          Penguin|    6|
# +-----------------+-----+

# %% [markdown]
# Untuk mengetahui lebih dalam, kenapa wide gunakan explain

# %%
grp_by = df.groupby('edition').count()
grp_by.explain()

df_filtered = df.filter("year_written > 1950 AND price > 10 AND title IS NOT NULL")
df_filtered.explain()
# Out:
# == Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=false
# +- HashAggregate(keys=[edition#152], functions=[count(1)])
#    +- Exchange hashpartitioning(edition#152, 200), ENSURE_REQUIREMENTS, [id=#562]
#       +- HashAggregate(keys=[edition#152], functions=[partial_count(1)])
#          +- FileScan json [edition#152] Batched: false, DataFilters: [], Format: JSON, Location: InMemoryFileIndex(1 paths)[file:/tmp/sample_books.json], PartitionFilters: [], PushedFilters: [], ReadSchema: struct<edition:string>
#
#
# == Physical Plan ==
# *(1) Filter ((((isnotnull(year_written#155L) AND isnotnull(price#153)) AND (year_written#155L > 1950)) AND (price#153 > 10.0)) AND isnotnull(title#154))
# +- FileScan json [_corrupt_record#150,author#151,edition#152,price#153,title#154,year_written#155L] Batched: false, DataFilters: [isnotnull(year_written#155L), isnotnull(price#153), (year_written#155L > 1950), (price#153 > 10...., Format: JSON, Location: InMemoryFileIndex(1 paths)[file:/tmp/sample_books.json], PartitionFilters: [], PushedFilters: [IsNotNull(year_written), IsNotNull(price), GreaterThan(year_written,1950), GreaterThan(price,10...., ReadSchema: struct<_corrupt_record:string,author:string,edition:string,price:double,title:string,year_written...

# %%
df = spark.read.json("/tmp/sample_books.json")

# %%
df.printSchema()
# Out:
# root
#  |-- author: string (nullable = true)
#  |-- edition: string (nullable = true)
#  |-- price: double (nullable = true)
#  |-- title: string (nullable = true)
#  |-- year_written: long (nullable = true)

# %%
df.show(4,False)
# Out:
# +---------------+--------------+-----+----------------+------------+
# |author         |edition       |price|title           |year_written|
# +---------------+--------------+-----+----------------+------------+
# |Austen, Jane   |Penguin       |18.2 |Northanger Abbey|1814        |
# |Tolstoy, Leo   |Penguin       |12.7 |War and Peace   |1865        |
# |Tolstoy, Leo   |Penguin       |13.5 |Anna Karenina   |1875        |
# |Woolf, Virginia|Harcourt Brace|25.0 |Mrs. Dalloway   |1925        |
# +---------------+--------------+-----+----------------+------------+
# only showing top 4 rows

# %%
df.count()
# Out:
# 13

# %%
df.select("title", "price", "year_written").show(5)
# Out:
# +----------------+-----+------------+
# |           title|price|year_written|
# +----------------+-----+------------+
# |Northanger Abbey| 18.2|        1814|
# |   War and Peace| 12.7|        1865|
# |   Anna Karenina| 13.5|        1875|
# |   Mrs. Dalloway| 25.0|        1925|
# |       The Hours|12.35|        1999|
# +----------------+-----+------------+
# only showing top 5 rows

# %%
df_filtered = df.filter("year_written > 1950 AND price > 10 AND title IS NOT NULL")
df_filtered.select("title", "price", "year_written").show(50, False)
# Out:
# +-----------------------------+-----+------------+
# |title                        |price|year_written|
# +-----------------------------+-----+------------+
# |The Hours                    |12.35|1999        |
# |Harry Potter                 |19.95|2000        |
# |One Hundred Years of Solitude|14.0 |1967        |
# +-----------------------------+-----+------------+
